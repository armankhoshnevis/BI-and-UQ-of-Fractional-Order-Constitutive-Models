# %% [markdown]
# ### Libraries

# %%
import json
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath(".."))
from Python_Scripts.Inference_Funcs_FMM import (
    load_data,
    modulus_func,
    define_bounds,
    inference_function,
    calculate_diagnostic_metrics,
    error_func,
    save_inference_results
)

# %%
HS = 20
with open(f'../Configs/{HS}HSWF_FMM_Config.json', 'r') as config_file:
    config = json.load(config_file)

file_path = config['file_path']
sheet_name = config['sheet_name']
rows = config['rows']
cols_opt = config['cols_opt']
cols_GnP = config['cols_GnP']
GnPs = config['GnPs']

# Update matplotlib rcParams
rcParams_plot = config['rcParams_plot']
plt.rcParams.update({
    'font.size': rcParams_plot['font.size'],
    'axes.labelsize': rcParams_plot['axes.labelsize'],
    'xtick.labelsize': rcParams_plot['xtick.labelsize'],
    'ytick.labelsize': rcParams_plot['ytick.labelsize'],
    'axes.titlesize': rcParams_plot['axes.titlesize'],
    'legend.fontsize': rcParams_plot['legend.fontsize'],
    'font.family': rcParams_plot['font.family'],
    'mathtext.fontset': rcParams_plot['mathtext.fontset'],
    'mathtext.rm': rcParams_plot['mathtext.rm'],
    'mathtext.it': rcParams_plot['mathtext.it'],
    'mathtext.bf': rcParams_plot['mathtext.bf'],
})

# Initialize some variables
idata_dict,  error_measures_dict = {}, {}
idata_mean_dict, idata_std_dict, map_estimate_dict = {}, {}, {}
idata_hdi_dict, Ep_Epp_hdi_dict, model_param_hdi_dict = {}, {}, {}
ess_quantile_05_dict, ess_quantile_95_dict = {}, {}
rhat_dict, ess_bulk_dict, mcse_dict = {}, {}, {}

param_list = ['E_c1', 'alpha_1', 'E_c2', 'alpha_2', 'sigma_Ep', 'sigma_Epp']
actual_param_name = [r'$E_{c_1}$', r'$\alpha_1$', r'$E_{c_2}$', r'$\alpha_2$',
                    r'$\sigma_{E^{\prime}}$', r'$\sigma_{E^{\prime\prime}}$']

omega_limits = config['omega_limits']

# Load the experimental data and optimized parameters
v_obs_Ep, v_obs_Epp, x_data, optimized_params_df = load_data(file_path, sheet_name, rows, cols_opt, cols_GnP, omega_limits, rcParams_plot)

# Perform inference for each nanocomposite system
for GnP_idx in range(len(GnPs)):
    print(f"Running inference for {GnPs[GnP_idx]}...")

    model_params_opt = optimized_params_df.iloc[GnP_idx]

    bounds = define_bounds(model_params_opt)
    bounds['sigma_Ep'] = (0, 1)
    bounds['sigma_Epp'] = (0, 1)

    exp_data = {
        'x_data': x_data[GnPs[GnP_idx]],
        'v_obs_Ep': v_obs_Ep[GnPs[GnP_idx]],
        'v_obs_Epp': v_obs_Epp[GnPs[GnP_idx]]
    }

    hyperparams = config['hyperparams']

    idata, map_estimate = inference_function(model_params_opt, bounds, exp_data, hyperparams)
    diagnostic_metrics = calculate_diagnostic_metrics(idata, param_list)
    
    idata_dict[GnPs[GnP_idx]] = idata
    map_estimate_dict[GnPs[GnP_idx]] = map_estimate
    rhat_dict[GnPs[GnP_idx]] = diagnostic_metrics['rhat_dict']
    ess_bulk_dict[GnPs[GnP_idx]] = diagnostic_metrics['ess_bulk_dict']
    ess_quantile_05_dict[GnPs[GnP_idx]] = diagnostic_metrics['ess_quantile_05_dict']
    ess_quantile_95_dict[GnPs[GnP_idx]] = diagnostic_metrics['ess_quantile_95_dict']
    mcse_dict[GnPs[GnP_idx]] = diagnostic_metrics['mcse_dict']

    idata_mean_dict[GnPs[GnP_idx]] = {}
    idata_std_dict[GnPs[GnP_idx]] = {}
    for key in param_list:
        idata_mean_dict[GnPs[GnP_idx]][key] = idata_dict[GnPs[GnP_idx]].posterior[key].values.flatten().mean()
        idata_std_dict[GnPs[GnP_idx]][key] = idata_dict[GnPs[GnP_idx]].posterior[key].values.flatten().std()

    map_estimate_dict[GnPs[GnP_idx]]['tau_c1'] = model_params_opt['tau_c1']
    map_estimate_dict[GnPs[GnP_idx]]['tau_c2'] = model_params_opt['tau_c2']
    map_estimate_dict[GnPs[GnP_idx]]['beta_1'] = model_params_opt['beta_1']
    idata_mean_dict[GnPs[GnP_idx]]['tau_c1'] = model_params_opt['tau_c1']
    idata_mean_dict[GnPs[GnP_idx]]['tau_c2'] = model_params_opt['tau_c2']
    idata_mean_dict[GnPs[GnP_idx]]['beta_1'] = model_params_opt['beta_1']

    error_measures_dict[GnPs[GnP_idx]] = error_func(
        exp_data['v_obs_Ep'], exp_data['v_obs_Epp'],
        modulus_func(exp_data['x_data'], model_params_opt, 'storage'),
        modulus_func(exp_data['x_data'], model_params_opt, 'loss'),
        modulus_func(exp_data['x_data'], idata_mean_dict[GnPs[GnP_idx]], 'storage'),
        modulus_func(exp_data['x_data'], idata_mean_dict[GnPs[GnP_idx]], 'loss'),
        modulus_func(exp_data['x_data'], map_estimate_dict[GnPs[GnP_idx]], 'storage'),
        modulus_func(exp_data['x_data'], map_estimate_dict[GnPs[GnP_idx]], 'loss'),
    )

to_be_saved = {
    "idata": idata_dict,
    "idata_mean": idata_mean_dict,
    "idata_std": idata_std_dict,
    "map_estimate": map_estimate_dict,
    "error_measures": error_measures_dict,
    "rhat": rhat_dict,
    "ess_bulk_dict": ess_bulk_dict,
    "ess_quantile_05_dict": ess_quantile_05_dict,
    "ess_quantile_95_dict": ess_quantile_95_dict,
    "mcse_dict": mcse_dict
}

save_inference_results(to_be_saved, file_path, HS)
# Out:
# Running inference for 0.0GnP...
# Initializing NUTS using jitter+adapt_diag...
# 03-24 09:40:21 - Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# 03-24 09:40:24 - Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:40:24 - NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:40:24 - Starting sampling for chain 0
# 03-24 09:40:26 - Chain 1: 5000/5000 samples drawn, Speed: 2435.10 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:26 - Completed sampling for chain 1
# 03-24 09:40:26 - Chain 0: 5000/5000 samples drawn, Speed: 2335.03 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:26 - Completed sampling for chain 0
# 03-24 09:40:26 - Chain 2: 5000/5000 samples drawn, Speed: 2324.27 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:26 - Completed sampling for chain 2
# 03-24 09:40:26 - Chain 3: 5000/5000 samples drawn, Speed: 2276.91 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:26 - Completed sampling for chain 3
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# 03-24 09:40:27 - Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# Sampling: [likelihood_Ep, likelihood_Epp]
# 03-24 09:40:31 - Sampling: [likelihood_Ep, likelihood_Epp]
# Running inference for 0.5GnP...
# Initializing NUTS using jitter+adapt_diag...
# 03-24 09:40:33 - Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# 03-24 09:40:36 - Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:40:36 - NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:40:36 - Starting sampling for chain 1
# 03-24 09:40:38 - Chain 0: 5000/5000 samples drawn, Speed: 2449.30 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:38 - Completed sampling for chain 0
# 03-24 09:40:38 - Chain 3: 5000/5000 samples drawn, Speed: 2408.68 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:38 - Completed sampling for chain 3
# 03-24 09:40:38 - Chain 1: 5000/5000 samples drawn, Speed: 2389.65 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:38 - Completed sampling for chain 1
# 03-24 09:40:38 - Chain 2: 5000/5000 samples drawn, Speed: 2349.87 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:38 - Completed sampling for chain 2
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# 03-24 09:40:38 - Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# Sampling: [likelihood_Ep, likelihood_Epp]
# 03-24 09:40:42 - Sampling: [likelihood_Ep, likelihood_Epp]
# Running inference for 1.0GnP...
# Initializing NUTS using jitter+adapt_diag...
# 03-24 09:40:44 - Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# 03-24 09:40:47 - Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:40:47 - NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:40:47 - Starting sampling for chain 1
# 03-24 09:40:49 - Chain 2: 5000/5000 samples drawn, Speed: 2497.10 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:49 - Completed sampling for chain 2
# 03-24 09:40:49 - Chain 0: 5000/5000 samples drawn, Speed: 2475.94 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:49 - Completed sampling for chain 0
# 03-24 09:40:49 - Chain 3: 5000/5000 samples drawn, Speed: 2447.86 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:49 - Completed sampling for chain 3
# 03-24 09:40:49 - Chain 1: 5000/5000 samples drawn, Speed: 2358.58 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:40:49 - Completed sampling for chain 1
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# 03-24 09:40:50 - Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# Sampling: [likelihood_Ep, likelihood_Epp]
# 03-24 09:40:57 - Sampling: [likelihood_Ep, likelihood_Epp]
# Running inference for 1.5GnP...
# Initializing NUTS using jitter+adapt_diag...
# 03-24 09:40:59 - Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# 03-24 09:41:02 - Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:41:02 - NUTS: [sigma_Ep, sigma_Epp, E_c1, alpha_1, alpha_2]
# 03-24 09:41:02 - Starting sampling for chain 2
# 03-24 09:41:04 - Chain 1: 5000/5000 samples drawn, Speed: 2329.43 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:41:04 - Completed sampling for chain 1
# 03-24 09:41:04 - Chain 3: 5000/5000 samples drawn, Speed: 2321.93 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:41:04 - Completed sampling for chain 3
# 03-24 09:41:04 - Chain 2: 5000/5000 samples drawn, Speed: 2213.62 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:41:04 - Completed sampling for chain 2
# 03-24 09:41:04 - Chain 0: 5000/5000 samples drawn, Speed: 2180.75 draws/s, Elapsed: 0:00:02, Remaining: 0:00:00
# 03-24 09:41:04 - Completed sampling for chain 0
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# 03-24 09:41:05 - Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 3 seconds.
# Sampling: [likelihood_Ep, likelihood_Epp]
# 03-24 09:41:08 - Sampling: [likelihood_Ep, likelihood_Epp]
# Saved inference data for 0.0GnP to ../Results/MCMC_FMM_40HSWF/EpEpp_FMM_40HS_0.0GnP.nc
# Saved inference data for 0.5GnP to ../Results/MCMC_FMM_40HSWF/EpEpp_FMM_40HS_0.5GnP.nc
# Saved inference data for 1.0GnP to ../Results/MCMC_FMM_40HSWF/EpEpp_FMM_40HS_1.0GnP.nc
# Saved inference data for 1.5GnP to ../Results/MCMC_FMM_40HSWF/EpEpp_FMM_40HS_1.5GnP.nc
# Done! ...
